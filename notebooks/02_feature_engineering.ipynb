# %% [markdown]
# # Phase 2 — Feature Engineering
#
# Run `scripts/feature_engineering.py` to compute longitudinal features
# (rolling averages, trajectory slope, consistency score, career phase)
# and Tool scores from `configs/tool_mapping.yaml`.
#
# Outputs: `data/nba_longitudinal_features.csv`, `data/nba_tool_scores.csv`
#
# See `plan.md §5 Phase 2` and `workflow.plan.md §1` for details.
