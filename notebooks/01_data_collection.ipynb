# %% [markdown]
# # Phase 1 — Data Collection
#
# Run `scripts/ingest_bbref.py`, `scripts/ingest_nba_api.py`, and `scripts/ingest_salary.py`
# to populate the `data/` directory with the raw panel CSV files.
#
# See `plan.md §4` and `plan.md §5 Phase 1` for details.
